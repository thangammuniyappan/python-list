# %%
mylist = ["hi", "hello", "welcome","welcome"]
print(mylist)
# Out:
# ['hi', 'hello', 'welcome', 'welcome']

# %%
print(len(mylist))

# %%
mylist = ["hi", 1, 0.1,1+4j]
print(mylist)
# Out:
# ['hi', 1, 0.1, (1+4j)]

# %%
print(True*True)
# Out:
# 1

# %%
gender=input("enter your gender")
exp=int(input("enter your exp"))


if gender=="male":
    if exp==1:
        print("TCS")
    elif exp==2:
        print("WIBRO")
    else:
        print("invalid")
elif gender=="female":
    if exp==2:
        print("TCS")
    elif exp==3:
        print("WIBRO")
    else:
        print("invalid")
else:
    print("invalid")
# Out:
# enter your gender male
# enter your exp 2
# WIBRO

# %%
skills=input("enter your gender")
exp=int(input("enter your exp"))


if skills=="python":
    if exp==1:
        print("TCS")
    elif exp==2:
        print("WIBRO")
    else:
        print("invalid")
elif skills=="java":
    if exp==2:
        print("TCS")
    elif exp==3:
        print("WIBRO")
    else:
        print("invalid")
else:
    print("invalid")
# Out:
# enter your gender python
# enter your exp 1
# TCS
